# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install Augmentor

# %%
# !cp "/content/drive/My Drive/ta/dataset_thai.zip" .
# !unzip dataset_thai.zip
# Out:
# Archive:  dataset_thai.zip
#    creating: dataset_thai/
#    creating: dataset_thai/test/
#    creating: dataset_thai/test/b/
#    creating: dataset_thai/test/ch1/
#    creating: dataset_thai/test/ch2/
#    creating: dataset_thai/test/ch3/
#    creating: dataset_thai/test/ch4/
#    creating: dataset_thai/test/d1/
#    creating: dataset_thai/test/d2/
#    creating: dataset_thai/test/f1/
#    creating: dataset_thai/test/f2/
#    creating: dataset_thai/test/h1/
#    creating: dataset_thai/test/h2/
#    creating: dataset_thai/test/k/
#    creating: dataset_thai/test/kh1/
#    creating: dataset_thai/test/kh2/
#    creating: dataset_thai/test/kh3/
#    creating: dataset_thai/test/kh4/
#    creating: dataset_thai/test/kh5/
#    creating: dataset_thai/test/l1/
#    creating: dataset_thai/test/l2/
#    creating: dataset_thai/test/m/
#    creating: dataset_thai/test/n1/
#    creating: dataset_thai/test/n2/
#    creating: dataset_thai/test/ng/
#    creating: dataset_thai/test/o/
# ...

# %% [markdown]
# ## Persiapan Dataset

# %%
# !cp dataset_thai/train/b/b.jpg /content/dataset_thai/test/b/
# !cp dataset_thai/train/ch1/ch1.jpg /content/dataset_thai/test/ch1/
# !cp dataset_thai/train/ch2/ch2.jpg /content/dataset_thai/test/ch2/
# !cp dataset_thai/train/ch3/ch3.jpg /content/dataset_thai/test/ch3/
# !cp dataset_thai/train/ch4/ch4.jpg /content/dataset_thai/test/ch4/
# !cp dataset_thai/train/d1/d1.jpg /content/dataset_thai/test/d1/
# !cp dataset_thai/train/d2/d2.jpg /content/dataset_thai/test/d2/
# !cp dataset_thai/train/f1/f1.jpg /content/dataset_thai/test/f1/
# !cp dataset_thai/train/f2/f2.jpg /content/dataset_thai/test/f2/
# !cp dataset_thai/train/h1/h1.jpg /content/dataset_thai/test/h1/
# !cp dataset_thai/train/h2/h2.jpg /content/dataset_thai/test/h2/
# !cp dataset_thai/train/k/k.jpg /content/dataset_thai/test/k/
# !cp dataset_thai/train/kh1/kh1.jpg /content/dataset_thai/test/kh1/
# !cp dataset_thai/train/kh2/kh2.jpg /content/dataset_thai/test/kh2/
# !cp dataset_thai/train/kh3/kh3.jpg /content/dataset_thai/test/kh3/
# !cp dataset_thai/train/kh4/kh4.jpg /content/dataset_thai/test/kh4/
# !cp dataset_thai/train/kh5/kh5.jpg /content/dataset_thai/test/kh5/
# !cp dataset_thai/train/l1/l1.jpg /content/dataset_thai/test/l1/
# !cp dataset_thai/train/l2/l2.jpg /content/dataset_thai/test/l2/
# !cp dataset_thai/train/m/m.jpg /content/dataset_thai/test/m/
# !cp dataset_thai/train/n1/n1.jpg /content/dataset_thai/test/n1/
# !cp dataset_thai/train/n2/n2.jpg /content/dataset_thai/test/n2/
# !cp dataset_thai/train/ng/ng.jpg /content/dataset_thai/test/ng/
# !cp dataset_thai/train/o/o.jpg /content/dataset_thai/test/o/
# !cp dataset_thai/train/p/p.jpg /content/dataset_thai/test/p/
# !cp dataset_thai/train/ph1/ph1.jpg /content/dataset_thai/test/ph1/
# !cp dataset_thai/train/ph2/ph2.jpg /content/dataset_thai/test/ph2/
# !cp dataset_thai/train/ph3/ph3.jpg /content/dataset_thai/test/ph3/
# !cp dataset_thai/train/r/r.jpg /content/dataset_thai/test/r/
# !cp dataset_thai/train/s1/s1.jpg /content/dataset_thai/test/s1/
# !cp dataset_thai/train/s2/s2.jpg /content/dataset_thai/test/s2/
# !cp dataset_thai/train/s3/s3.jpg /content/dataset_thai/test/s3/
# !cp dataset_thai/train/s4/s4.jpg /content/dataset_thai/test/s4/
# !cp dataset_thai/train/t1/t1.jpg /content/dataset_thai/test/t1/
# !cp dataset_thai/train/t2/t2.jpg /content/dataset_thai/test/t2/
# !cp dataset_thai/train/th1/th1.jpg /content/dataset_thai/test/th1/
# !cp dataset_thai/train/th2/th2.jpg /content/dataset_thai/test/th2/
# !cp dataset_thai/train/th3/th3.jpg /content/dataset_thai/test/th3/
# !cp dataset_thai/train/th4/th4.jpg /content/dataset_thai/test/th4/
# !cp dataset_thai/train/th5/th5.jpg /content/dataset_thai/test/th5/
# !cp dataset_thai/train/th6/th6.jpg /content/dataset_thai/test/th6/
# !cp dataset_thai/train/w/w.jpg /content/dataset_thai/test/w/
# !cp dataset_thai/train/y1/y1.jpg /content/dataset_thai/test/y1/
# !cp dataset_thai/train/y2/y2.jpg /content/dataset_thai/test/y2/

# %%
import Augmentor
import os

def perbanyak_(ini, sebanyak_ini):
  source_dir = ini
  output_dir = "."
  p = Augmentor.Pipeline(source_directory=source_dir, output_directory=output_dir)
  p.random_distortion(probability=1, grid_width=4, grid_height=4, magnitude=1)
  p.rotate(probability=0.7, max_left_rotation=13, max_right_rotation=13)
  p.zoom_random(probability=0.5, percentage_area=0.9)
  p.crop_random(probability=0.6, percentage_area=0.9)
  p.resize(probability=1.0, width=64, height=64)

  p.sample(sebanyak_ini)

perbanyak_("dataset_thai/test/b/", 30)
perbanyak_("dataset_thai/test/ch1/", 30)
perbanyak_("dataset_thai/test/ch2/", 30)
perbanyak_("dataset_thai/test/ch3/", 30)
perbanyak_("dataset_thai/test/ch4/", 30)
perbanyak_("dataset_thai/test/d1/", 30)
perbanyak_("dataset_thai/test/d2/", 30)
perbanyak_("dataset_thai/test/f1/", 30)
perbanyak_("dataset_thai/test/f2/", 30)
perbanyak_("dataset_thai/test/h1/", 30)
perbanyak_("dataset_thai/test/h2/", 30)
perbanyak_("dataset_thai/test/k/", 30)
perbanyak_("dataset_thai/test/kh1/", 30)
perbanyak_("dataset_thai/test/kh2/", 30)
perbanyak_("dataset_thai/test/kh3/", 30)
perbanyak_("dataset_thai/test/kh4/", 30)
perbanyak_("dataset_thai/test/kh5/", 30)
perbanyak_("dataset_thai/test/l1/", 30)
perbanyak_("dataset_thai/test/l2/", 30)
perbanyak_("dataset_thai/test/m/", 30)
perbanyak_("dataset_thai/test/n1/", 30)
perbanyak_("dataset_thai/test/n2/", 30)
perbanyak_("dataset_thai/test/ng/", 30)
perbanyak_("dataset_thai/test/o/", 30)
perbanyak_("dataset_thai/test/p/", 30)
perbanyak_("dataset_thai/test/ph1/", 30)
perbanyak_("dataset_thai/test/ph2/", 30)
perbanyak_("dataset_thai/test/ph3/", 30)
perbanyak_("dataset_thai/test/r/", 30)
perbanyak_("dataset_thai/test/s1/", 30)
perbanyak_("dataset_thai/test/s2/", 30)
perbanyak_("dataset_thai/test/s3/", 30)
perbanyak_("dataset_thai/test/s4/", 30)
perbanyak_("dataset_thai/test/t1/", 30)
perbanyak_("dataset_thai/test/t2/", 30)
perbanyak_("dataset_thai/test/th1/", 30)
perbanyak_("dataset_thai/test/th2/", 30)
perbanyak_("dataset_thai/test/th3/", 30)
perbanyak_("dataset_thai/test/th4/", 30)
perbanyak_("dataset_thai/test/th5/", 30)
perbanyak_("dataset_thai/test/th6/", 30)
perbanyak_("dataset_thai/test/w/", 30)
perbanyak_("dataset_thai/test/y1/", 30)
perbanyak_("dataset_thai/test/y2/", 30)

perbanyak_("dataset_thai/train/b/", 270)
perbanyak_("dataset_thai/train/ch1/", 270)
perbanyak_("dataset_thai/train/ch2/", 270)
perbanyak_("dataset_thai/train/ch3/", 270)
perbanyak_("dataset_thai/train/ch4/", 270)
perbanyak_("dataset_thai/train/d1/", 270)
perbanyak_("dataset_thai/train/d2/", 270)
perbanyak_("dataset_thai/train/f1/", 270)
perbanyak_("dataset_thai/train/f2/", 270)
perbanyak_("dataset_thai/train/h1/", 270)
perbanyak_("dataset_thai/train/h2/", 270)
perbanyak_("dataset_thai/train/k/", 270)
perbanyak_("dataset_thai/train/kh1/", 270)
perbanyak_("dataset_thai/train/kh2/", 270)
perbanyak_("dataset_thai/train/kh3/", 270)
perbanyak_("dataset_thai/train/kh4/", 270)
perbanyak_("dataset_thai/train/kh5/", 270)
perbanyak_("dataset_thai/train/l1/", 270)
perbanyak_("dataset_thai/train/l2/", 270)
perbanyak_("dataset_thai/train/m/", 270)
perbanyak_("dataset_thai/train/n1/", 270)
perbanyak_("dataset_thai/train/n2/", 270)
perbanyak_("dataset_thai/train/ng/", 270)
perbanyak_("dataset_thai/train/o/", 270)
perbanyak_("dataset_thai/train/p/", 270)
perbanyak_("dataset_thai/train/ph1/", 270)
perbanyak_("dataset_thai/train/ph2/", 270)
perbanyak_("dataset_thai/train/ph3/", 270)
perbanyak_("dataset_thai/train/r/", 270)
perbanyak_("dataset_thai/train/s1/", 270)
perbanyak_("dataset_thai/train/s2/", 270)
perbanyak_("dataset_thai/train/s3/", 270)
perbanyak_("dataset_thai/train/s4/", 270)
perbanyak_("dataset_thai/train/t1/", 270)
perbanyak_("dataset_thai/train/t2/", 270)
perbanyak_("dataset_thai/train/th1/", 270)
perbanyak_("dataset_thai/train/th2/", 270)
perbanyak_("dataset_thai/train/th3/", 270)
perbanyak_("dataset_thai/train/th4/", 270)
perbanyak_("dataset_thai/train/th5/", 270)
perbanyak_("dataset_thai/train/th6/", 270)
perbanyak_("dataset_thai/train/w/", 270)
perbanyak_("dataset_thai/train/y1/", 270)
perbanyak_("dataset_thai/train/y2/", 270)
# Out:
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F96FD03DDD0>:  33%|███▎      | 10/30 [00:00<00:00, 27.15 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to dataset_thai/test/b/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F96F7DC0A90>: 100%|██████████| 30/30 [00:00<00:00, 123.46 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F96FD03DC50>:  47%|████▋     | 14/30 [00:00<00:00, 35.56 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to dataset_thai/test/ch1/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F96F7DCD9D0>: 100%|██████████| 30/30 [00:00<00:00, 129.16 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F96F7DE2890>:  70%|███████   | 21/30 [00:00<00:00, 29.71 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to dataset_thai/test/ch2/..
# ...

# %% [markdown]
# Sekarang, mari perbanyak masing-masing dataset train dan test dengan Augmentor.

# %% [markdown]
# Dan jangan lupa, hapuslah file original `5.png` dan `s.png` dari folder `train` untuk kita sisakan file original di folder `test`. Dengan ini kita mendapatkan 270 varian gambar 5 dan 270 varian gambar s untuk training, dan kita juga mendapatkan 31 varian gambar 5 dan 31 varian gambar s untuk testing.

# %%
#!rm dataset/train/5/lima.png
#!rm dataset/train/s/s.png
#!rm dataset/train/w/w.png

# !rm -rf dataset_pho

# %% [markdown]
# ## FIle Training
#
# Berikut adalah teknik untuk menampilkan 20 file yang ada pada folder `train/5` dan test `test/s`. Gunakan `glob` untuk mengambil daftar file pada suatu folder.
#
# Jika anda menggunakan `jupyter notebook`, maka tambahkanlah baris `%matplotlib inline` di bawah `import matplotlib.pyplot as plt` untuk mengaktifkan penampil fungsi plot pada `notebook` anda.

# %%
import glob
import matplotlib.pyplot as plt
#%matplotlib inline

def tampilkan_6_kali_5_gambar_pada_alamat(ini):
  a = glob.glob(ini)

  w=10
  h=10
  fig=plt.figure(figsize=(8, 8))
  columns = 6
  rows = 5
  for i in range(1, columns*rows +1):
      img = plt.imread(a[i])
      fig.add_subplot(rows, columns, i)
      plt.imshow(img)
  plt.show()

# %%
tampilkan_6_kali_5_gambar_pada_alamat("dataset_thai/train/ch1/*")

# %%
tampilkan_6_kali_5_gambar_pada_alamat("dataset_thai/test/y1/*")

# %% [markdown]
# ## Fase Training
#
# Pada fase training ini, dipergunakan arsitektur CNN sederhana yang terdiri atas 1 layer konvolusi, 1 layer pooling, 1 layer flatten, yang terkoneksi dengan 2 fully connected layer lainnya.
#
# Hasil akhir penentuan ada pada bagian node paling akhir di mana
#
# `model.add(Dense(units = 1, activation = 'sigmoid'))`

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation
from keras.preprocessing.image import ImageDataGenerator
from keras.metrics import categorical_accuracy


size_ = 16

model = Sequential()

model.add(Conv2D(4, (3, 3), input_shape = (size_, size_, 3), activation = 'relu'))
model.add(Conv2D(8, (3, 3), input_shape = (size_, size_, 3), activation = 'relu'))
model.add(Conv2D(16, (3, 3), input_shape = (size_, size_, 3), activation = 'relu'))
#model.add(Conv2D(32, (3, 3), input_shape = (size_, size_, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Flatten())

model.add(Dense(units = 10, activation = 'relu'))
model.add(Dense(units = 44, activation = 'softmax'))

model.compile(optimizer = 'sgd', loss = 'categorical_crossentropy', metrics = [categorical_accuracy])

# %% [markdown]
# Berikut adalah arsitektur akhir CNN yang akan kita pergunakan.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 14, 14, 4)         112
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 12, 12, 8)         296
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 16)        1168
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                4010
# _________________________________________________________________
# dense_1 (Dense)              (None, 44)                484
# ...

# %% [markdown]
# Sekarang, mari kita set konfigurasi di mana lokasi data train dan data test kita berada.

# %%
train = ImageDataGenerator(rescale = 1./255)
test = ImageDataGenerator(rescale = 1./255)
train_data = train.flow_from_directory('dataset_thai/train', target_size = (size_, size_), batch_size = 32, class_mode = 'categorical')
test_data = test.flow_from_directory('dataset_thai/test', target_size = (size_, size_), batch_size = 32, class_mode = 'categorical')
# Out:
# Found 11924 images belonging to 44 classes.
# Found 1364 images belonging to 44 classes.

# %% [markdown]
# Pastikan isi folder `dataset/train`nya hanya terdiri atas 2 folder saja, tanpa ada folder tambahan `.ipynb_checkpoints`.

# %%
# !ls -al dataset_thai/train/
# Out:
# total 1440
# drwxr-xr-x 46 root root  4096 Apr  3  2021 .
# drwxr-xr-x  4 root root  4096 Apr  3  2021 ..
# drwxr-xr-x  2 root root 32768 Apr  3 04:20 b
# drwxr-xr-x  2 root root 36864 Apr  3 04:20 ch1
# drwxr-xr-x  2 root root 32768 Apr  3 04:20 ch2
# drwxr-xr-x  2 root root 32768 Apr  3 04:20 ch3
# drwxr-xr-x  2 root root 28672 Apr  3 04:20 ch4
# drwxr-xr-x  2 root root 36864 Apr  3 04:20 d1
# drwxr-xr-x  2 root root 28672 Apr  3 04:20 d2
# drwxr-xr-x  2 root root 28672 Apr  3 04:20 f1
# drwxr-xr-x  2 root root 32768 Apr  3 04:20 f2
# drwxr-xr-x  2 root root 32768 Apr  3 04:20 h1
# drwxr-xr-x  2 root root 32768 Apr  3 04:21 h2
# drwxr-xr-x  2 root root 32768 Apr  3 04:21 k
# drwxr-xr-x  2 root root 32768 Apr  3 04:21 kh1
# drwxr-xr-x  2 root root 32768 Apr  3 04:21 kh2
# drwxr-xr-x  2 root root 32768 Apr  3 04:21 kh3
# drwxr-xr-x  2 root root 36864 Apr  3 04:21 kh4
# drwxr-xr-x  2 root root 32768 Apr  3 04:21 kh5
# drwxr-xr-x  2 root root 32768 Apr  3 04:21 l1
# ...

# %% [markdown]
# Sekarang, mari kita train model kita menggunakan 10 kali epoch (perulangan).

# %%
model.fit_generator(train_data, steps_per_epoch = 100, epochs = 100, validation_data = test_data, validation_steps = 100)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# ...
# 100/100 [==============================] - 3s 26ms/step - loss: 3.7855 - categorical_accuracy: 0.0308 - val_loss: 3.7822 - val_categorical_accuracy: 0.0367
# Epoch 2/100
# 100/100 [==============================] - 2s 18ms/step - loss: 3.7787 - categorical_accuracy: 0.0410
# Epoch 3/100
# 100/100 [==============================] - 2s 18ms/step - loss: 3.7773 - categorical_accuracy: 0.0368
# Epoch 4/100
# 100/100 [==============================] - 2s 18ms/step - loss: 3.7736 - categorical_accuracy: 0.0459
# Epoch 5/100
# 100/100 [==============================] - 2s 18ms/step - loss: 3.7694 - categorical_accuracy: 0.0428
# Epoch 6/100
# ...

# %% [markdown]
# Seperti yang bisa dilihat, jika model anda sudah benar, maka seharusnya nilai akurasi akan meningkat perlahan hingga mendekati 1.000 (alias 100%).

# %% [markdown]
# ## Fase Testing
#
# Pada fase ini, mari kita test keakuratan model yang sudah kita buat, apakah dia benar-benar bisa mengenali gambar `5` dan `s` dengan benar. Mari kita ambil 2 contoh file yang akan kita coba test keakuratan modelnya.

# %%
Tesch1 = "dataset_thai/test/ch1/ch1.jpg"
Tesch2 = "dataset_thai/test/ch2/ch2.jpg"
Tesy1 = "dataset_thai/test/y1/y1.jpg"

# %% [markdown]
# Berikut adalah isi kedua gambar yang akan kita test.

# %%
def tampilkan_(ini):
  fig = plt.figure(figsize=(2, 2))
  img = plt.imread(ini)
  plt.imshow(img)
  plt.show()

tampilkan_(Tesch1)
tampilkan_(Tesch2)
tampilkan_(Tesy1)

# %% [markdown]
# Karena hasil prediksi dalam bentuk angka, maka kita perlu membangun kamus, yang mana hasil prediksi tadi yang masih berupa angka, ditautkan dengan nama sebenarnya. Berikut adalah teknik membangun kamus tersebut.

# %%
def switch_dict_key_values(this_dict):
    return dict((v,k) for k,v in this_dict.items())

nama_train_data = switch_dict_key_values(train_data.class_indices)
print(nama_train_data)
# Out:
# {0: 'b', 1: 'ch1', 2: 'ch2', 3: 'ch3', 4: 'ch4', 5: 'd1', 6: 'd2', 7: 'f1', 8: 'f2', 9: 'h1', 10: 'h2', 11: 'k', 12: 'kh1', 13: 'kh2', 14: 'kh3', 15: 'kh4', 16: 'kh5', 17: 'l1', 18: 'l2', 19: 'm', 20: 'n1', 21: 'n2', 22: 'ng', 23: 'o', 24: 'p', 25: 'ph1', 26: 'ph2', 27: 'ph3', 28: 'r', 29: 's1', 30: 's2', 31: 's3', 32: 's4', 33: 't1', 34: 't2', 35: 'th1', 36: 'th2', 37: 'th3', 38: 'th4', 39: 'th5', 40: 'th6', 41: 'w', 42: 'y1', 43: 'y2'}

# %% [markdown]
# Sekarang terlihat bahwa `0` merepresentasikan `X` dan `1` merepresentasikan `X` dst.
#
# Untuk test pertama kita, mari kita coba `X` terlebih dahulu.

# %%
from keras.preprocessing import image
import numpy as np

img = image.load_img(Tesch1, target_size = (size_, size_))
img = image.img_to_array(img)
img = np.expand_dims(img, axis = 0)

hasil = model.predict_classes(img)
print("File gambar [", "CH1", "] diprediksi sebagai", hasil, "alias terbaca sebagai :: ", nama_train_data[hasil[0]], ".")
# Out:
# File gambar [ CH1 ] diprediksi sebagai [1] alias terbaca sebagai ::  ch1 .
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %% [markdown]
# Untuk test kedua kita, mari kita coba `s` sebagai file testing.

# %%
img = image.load_img(Tesch2, target_size = (size_, size_))
img = image.img_to_array(img)
img = np.expand_dims(img, axis = 0)

hasil = model.predict_classes(img)
print("File gambar [", "CH2", "] diprediksi sebagai", hasil, "alias terbaca sebagai :: ", nama_train_data[hasil[0]], ".")
# Out:
# File gambar [ CH2 ] diprediksi sebagai [2] alias terbaca sebagai ::  ch2 .
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
img = image.load_img(Tesy1, target_size = (size_, size_))
img = image.img_to_array(img)
img = np.expand_dims(img, axis = 0)

hasil = model.predict_classes(img)
print("File gambar [", "Y1", "] diprediksi sebagai", hasil, "alias terbaca sebagai :: ", nama_train_data[hasil[0]], ".")
# Out:
# File gambar [ Y1 ] diprediksi sebagai [42] alias terbaca sebagai ::  y1 .
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
lol = glob.glob("dataset_thai/test/ch1/*.jpg")

total = 0
for haha in lol:
  img = image.load_img(haha, target_size = (16, 16))
  img = image.img_to_array(img)
  img = np.expand_dims(img, axis = 0)

  hasil = model.predict_classes(img)
  #print("File gambar [s] diprediksi sebagai", hasil, "alias terbaca sebagai :: ", nama_train_data[hasil[0][0]], ".")
  total += (1 == hasil[0])*1
print(total/len(lol))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 0.967741935483871

# %%
lol = glob.glob("dataset_thai/test/y1/*.jpg")

total = 0
for haha in lol:
  img = image.load_img(haha, target_size = (16, 16))
  img = image.img_to_array(img)
  img = np.expand_dims(img, axis = 0)

  hasil = model.predict_classes(img)
  #print("File gambar [s] diprediksi sebagai", hasil, "alias terbaca sebagai :: ", nama_train_data[hasil[0][0]], ".")
  total += (42 == hasil[0])*1
print(total/len(lol))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 0.967741935483871
