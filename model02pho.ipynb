# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install Augmentor

# %%
# !cp "/content/drive/My Drive/ta/dataset_phoo.zip" .
# !unzip dataset_phoo.zip
# Out:
# Archive:  dataset_phoo.zip
#    creating: dataset_pho/
#    creating: dataset_pho/test/
#    creating: dataset_pho/test/B/
#    creating: dataset_pho/test/D/
#    creating: dataset_pho/test/G/
#    creating: dataset_pho/test/H/
#    creating: dataset_pho/test/H1/
#    creating: dataset_pho/test/K/
#    creating: dataset_pho/test/koma/
#    creating: dataset_pho/test/L/
#    creating: dataset_pho/test/M/
#    creating: dataset_pho/test/N/
#    creating: dataset_pho/test/P/
#    creating: dataset_pho/test/petik/
#    creating: dataset_pho/test/Q/
#    creating: dataset_pho/test/R/
#    creating: dataset_pho/test/S/
#    creating: dataset_pho/test/S1/
#    creating: dataset_pho/test/S2/
#    creating: dataset_pho/test/T/
#    creating: dataset_pho/test/T1/
#    creating: dataset_pho/test/W/
#    creating: dataset_pho/test/Y/
#    creating: dataset_pho/test/Z/
#    creating: dataset_pho/train/
#    creating: dataset_pho/train/B/
#   inflating: dataset_pho/train/B/B.jpg
# ...

# %% [markdown]
# ## Persiapan Dataset

# %%
# !cp dataset_pho/train/B/B.jpg /content/dataset_pho/test/B/
# !cp dataset_pho/train/D/D.jpg /content/dataset_pho/test/D/
# !cp dataset_pho/train/G/G.jpg /content/dataset_pho/test/G/
# !cp dataset_pho/train/H/H.jpg /content/dataset_pho/test/H/
# !cp dataset_pho/train/H1/H1.jpg /content/dataset_pho/test/H1/
# !cp dataset_pho/train/K/K.jpg /content/dataset_pho/test/K/
# !cp dataset_pho/train/koma/koma.jpg /content/dataset_pho/test/koma/
# !cp dataset_pho/train/L/L.jpg /content/dataset_pho/test/L/
# !cp dataset_pho/train/M/M.jpg /content/dataset_pho/test/M/
# !cp dataset_pho/train/N/N.jpg /content/dataset_pho/test/N/
# !cp dataset_pho/train/P/P.jpg /content/dataset_pho/test/P/
# !cp dataset_pho/train/petik/petik.jpg /content/dataset_pho/test/petik/
# !cp dataset_pho/train/Q/Q.jpg /content/dataset_pho/test/Q/
# !cp dataset_pho/train/R/R.jpg /content/dataset_pho/test/R/
# !cp dataset_pho/train/S/S.jpg /content/dataset_pho/test/S/
# !cp dataset_pho/train/S1/S1.jpg /content/dataset_pho/test/S1/
# !cp dataset_pho/train/S2/S2.jpg /content/dataset_pho/test/S2/
# !cp dataset_pho/train/T/T.jpg /content/dataset_pho/test/T/
# !cp dataset_pho/train/T1/T1.jpg /content/dataset_pho/test/T1/
# !cp dataset_pho/train/W/W.jpg /content/dataset_pho/test/W/
# !cp dataset_pho/train/Y/Y.jpg /content/dataset_pho/test/Y/
# !cp dataset_pho/train/Z/Z.jpg /content/dataset_pho/test/Z/

# %%
import Augmentor
import os

def perbanyak_(ini, sebanyak_ini):
  source_dir = ini
  output_dir = "."
  p = Augmentor.Pipeline(source_directory=source_dir, output_directory=output_dir)
  p.random_distortion(probability=1, grid_width=4, grid_height=4, magnitude=1)
  p.rotate(probability=0.7, max_left_rotation=13, max_right_rotation=13)
  p.zoom_random(probability=0.5, percentage_area=0.9)
  p.crop_random(probability=0.6, percentage_area=0.9)
  p.resize(probability=1.0, width=64, height=64)

  p.sample(sebanyak_ini)

perbanyak_("dataset_pho/test/B/", 30)
perbanyak_("dataset_pho/test/D/", 30)
perbanyak_("dataset_pho/test/G/", 30)
perbanyak_("dataset_pho/test/H/", 30)
perbanyak_("dataset_pho/test/H1/", 30)
perbanyak_("dataset_pho/test/K/", 30)
perbanyak_("dataset_pho/test/koma/", 30)
perbanyak_("dataset_pho/test/L/", 30)
perbanyak_("dataset_pho/test/M/", 30)
perbanyak_("dataset_pho/test/N/", 30)
perbanyak_("dataset_pho/test/P/", 30)
perbanyak_("dataset_pho/test/petik/", 30)
perbanyak_("dataset_pho/test/Q/", 30)
perbanyak_("dataset_pho/test/R/", 30)
perbanyak_("dataset_pho/test/S/", 30)
perbanyak_("dataset_pho/test/S1/", 30)
perbanyak_("dataset_pho/test/S2/", 30)
perbanyak_("dataset_pho/test/T/", 30)
perbanyak_("dataset_pho/test/T1/", 30)
perbanyak_("dataset_pho/test/W/", 30)
perbanyak_("dataset_pho/test/Y/", 30)
perbanyak_("dataset_pho/test/Z/", 30)

perbanyak_("dataset_pho/train/B/", 270)
perbanyak_("dataset_pho/train/D/", 270)
perbanyak_("dataset_pho/train/G/", 270)
perbanyak_("dataset_pho/train/H/", 270)
perbanyak_("dataset_pho/train/H1/", 270)
perbanyak_("dataset_pho/train/K/", 270)
perbanyak_("dataset_pho/train/koma/", 270)
perbanyak_("dataset_pho/train/L/", 270)
perbanyak_("dataset_pho/train/M/", 270)
perbanyak_("dataset_pho/train/N/", 270)
perbanyak_("dataset_pho/train/P/", 270)
perbanyak_("dataset_pho/train/petik/", 270)
perbanyak_("dataset_pho/train/Q/", 270)
perbanyak_("dataset_pho/train/R/", 270)
perbanyak_("dataset_pho/train/S/", 270)
perbanyak_("dataset_pho/train/S1/", 270)
perbanyak_("dataset_pho/train/S2/", 270)
perbanyak_("dataset_pho/train/T/", 270)
perbanyak_("dataset_pho/train/T1/", 270)
perbanyak_("dataset_pho/train/W/", 270)
perbanyak_("dataset_pho/train/Y/", 270)
perbanyak_("dataset_pho/train/Z/", 270)
# Out:
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7FB711F1E790>:  80%|████████  | 24/30 [00:00<00:00, 69.97 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to dataset_pho/test/B/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7FB70CCABC10>: 100%|██████████| 30/30 [00:00<00:00, 192.89 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7FB711F1EC90>:  67%|██████▋   | 20/30 [00:00<00:00, 25.97 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to dataset_pho/test/D/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7FB70CCBD690>: 100%|██████████| 30/30 [00:00<00:00, 132.78 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7FB70CCC3690>:  63%|██████▎   | 19/30 [00:00<00:00, 43.50 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to dataset_pho/test/G/..
# ...

# %% [markdown]
# Sekarang, mari perbanyak masing-masing dataset train dan test dengan Augmentor.

# %% [markdown]
# Dan jangan lupa, hapuslah file original `5.png` dan `s.png` dari folder `train` untuk kita sisakan file original di folder `test`. Dengan ini kita mendapatkan 270 varian gambar 5 dan 270 varian gambar s untuk training, dan kita juga mendapatkan 31 varian gambar 5 dan 31 varian gambar s untuk testing.

# %%
#!rm dataset/train/5/lima.png
#!rm dataset/train/s/s.png
#!rm dataset/train/w/w.png

# !rm -rf dataset_pho

# %% [markdown]
# ## FIle Training
#
# Berikut adalah teknik untuk menampilkan 20 file yang ada pada folder `train/5` dan test `test/s`. Gunakan `glob` untuk mengambil daftar file pada suatu folder.
#
# Jika anda menggunakan `jupyter notebook`, maka tambahkanlah baris `%matplotlib inline` di bawah `import matplotlib.pyplot as plt` untuk mengaktifkan penampil fungsi plot pada `notebook` anda.

# %%
import glob
import matplotlib.pyplot as plt
#%matplotlib inline

def tampilkan_6_kali_5_gambar_pada_alamat(ini):
  a = glob.glob(ini)

  w=10
  h=10
  fig=plt.figure(figsize=(8, 8))
  columns = 6
  rows = 5
  for i in range(1, columns*rows +1):
      img = plt.imread(a[i])
      fig.add_subplot(rows, columns, i)
      plt.imshow(img)
  plt.show()

# %%
tampilkan_6_kali_5_gambar_pada_alamat("dataset_pho/train/S1/*")

# %%
tampilkan_6_kali_5_gambar_pada_alamat("dataset_pho/test/S/*")

# %% [markdown]
# ## Fase Training
#
# Pada fase training ini, dipergunakan arsitektur CNN sederhana yang terdiri atas 1 layer konvolusi, 1 layer pooling, 1 layer flatten, yang terkoneksi dengan 2 fully connected layer lainnya.
#
# Hasil akhir penentuan ada pada bagian node paling akhir di mana
#
# `model.add(Dense(units = 1, activation = 'sigmoid'))`

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation
from keras.preprocessing.image import ImageDataGenerator
from keras.metrics import categorical_accuracy


size_ = 16

model = Sequential()

model.add(Conv2D(4, (3, 3), input_shape = (size_, size_, 3), activation = 'relu'))
model.add(Conv2D(8, (3, 3), input_shape = (size_, size_, 3), activation = 'relu'))
model.add(Conv2D(16, (3, 3), input_shape = (size_, size_, 3), activation = 'relu'))
#model.add(Conv2D(32, (3, 3), input_shape = (size_, size_, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Flatten())

model.add(Dense(units = 10, activation = 'relu'))
model.add(Dense(units = 22, activation = 'softmax'))

model.compile(optimizer = 'sgd', loss = 'categorical_crossentropy', metrics = [categorical_accuracy])

# %% [markdown]
# Berikut adalah arsitektur akhir CNN yang akan kita pergunakan.

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_17 (Conv2D)           (None, 14, 14, 4)         112
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 12, 12, 8)         296
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 10, 10, 16)        1168
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 400)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                4010
# _________________________________________________________________
# dense_11 (Dense)             (None, 62)                682
# ...

# %% [markdown]
# Sekarang, mari kita set konfigurasi di mana lokasi data train dan data test kita berada.

# %%
train = ImageDataGenerator(rescale = 1./255)
test = ImageDataGenerator(rescale = 1./255)
train_data = train.flow_from_directory('dataset_pho/train', target_size = (size_, size_), batch_size = 32, class_mode = 'categorical')
test_data = test.flow_from_directory('dataset_pho/test', target_size = (size_, size_), batch_size = 32, class_mode = 'categorical')
# Out:
# Found 5962 images belonging to 22 classes.
# Found 682 images belonging to 22 classes.

# %% [markdown]
# Pastikan isi folder `dataset/train`nya hanya terdiri atas 2 folder saja, tanpa ada folder tambahan `.ipynb_checkpoints`.

# %%
# !ls -al dataset_pho/train/
# Out:
# total 704
# drwxr-xr-x 24 root root  4096 Sep 12  2020 .
# drwxr-xr-x  4 root root  4096 Mar 29 06:07 ..
# drwxr-xr-x  2 root root 32768 Mar 29 23:45 B
# drwxr-xr-x  2 root root 28672 Mar 29 23:45 D
# drwxr-xr-x  2 root root 36864 Mar 29 23:45 G
# drwxr-xr-x  2 root root 28672 Mar 29 23:45 H
# drwxr-xr-x  2 root root 32768 Mar 29 23:45 H1
# drwxr-xr-x  2 root root 32768 Mar 29 23:45 K
# drwxr-xr-x  2 root root 32768 Mar 29 23:45 koma
# drwxr-xr-x  2 root root 28672 Mar 29 23:45 L
# drwxr-xr-x  2 root root 36864 Mar 29 23:45 M
# drwxr-xr-x  2 root root 36864 Mar 29 23:46 N
# drwxr-xr-x  2 root root 28672 Mar 29 23:46 P
# drwxr-xr-x  2 root root 32768 Mar 29 23:46 petik
# drwxr-xr-x  2 root root 32768 Mar 29 23:46 Q
# drwxr-xr-x  2 root root 36864 Mar 29 23:46 R
# drwxr-xr-x  2 root root 32768 Mar 29 23:46 S
# drwxr-xr-x  2 root root 28672 Mar 29 23:46 S1
# drwxr-xr-x  2 root root 36864 Mar 29 23:46 S2
# drwxr-xr-x  2 root root 32768 Mar 29 23:46 T
# ...

# %% [markdown]
# Sekarang, mari kita train model kita menggunakan 10 kali epoch (perulangan).

# %%
model.fit_generator(train_data, steps_per_epoch = 100, epochs = 100, validation_data = test_data, validation_steps = 100)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# ...
# 100/100 [==============================] - 3s 27ms/step - loss: 3.0802 - categorical_accuracy: 0.0480 - val_loss: 3.0612 - val_categorical_accuracy: 0.0513
# Epoch 2/100
# 100/100 [==============================] - 2s 20ms/step - loss: 3.0465 - categorical_accuracy: 0.0699
# Epoch 3/100
# 100/100 [==============================] - 2s 22ms/step - loss: 2.9721 - categorical_accuracy: 0.0821
# Epoch 4/100
# 100/100 [==============================] - 2s 22ms/step - loss: 2.8197 - categorical_accuracy: 0.1375
# Epoch 5/100
# 100/100 [==============================] - 2s 21ms/step - loss: 2.5078 - categorical_accuracy: 0.2289
# Epoch 6/100
# ...

# %% [markdown]
# Seperti yang bisa dilihat, jika model anda sudah benar, maka seharusnya nilai akurasi akan meningkat perlahan hingga mendekati 1.000 (alias 100%).

# %% [markdown]
# ## Fase Testing
#
# Pada fase ini, mari kita test keakuratan model yang sudah kita buat, apakah dia benar-benar bisa mengenali gambar `5` dan `s` dengan benar. Mari kita ambil 2 contoh file yang akan kita coba test keakuratan modelnya.

# %%
TesB = "dataset_pho/test/B/B.jpg"
TesD = "dataset_pho/test/D/D.jpg"
TesG = "dataset_pho/test/G/G.jpg"

# %% [markdown]
# Berikut adalah isi kedua gambar yang akan kita test.

# %%
def tampilkan_(ini):
  fig = plt.figure(figsize=(2, 2))
  img = plt.imread(ini)
  plt.imshow(img)
  plt.show()

tampilkan_(TesB)
tampilkan_(TesD)
tampilkan_(TesG)

# %% [markdown]
# Karena hasil prediksi dalam bentuk angka, maka kita perlu membangun kamus, yang mana hasil prediksi tadi yang masih berupa angka, ditautkan dengan nama sebenarnya. Berikut adalah teknik membangun kamus tersebut.

# %%
def switch_dict_key_values(this_dict):
    return dict((v,k) for k,v in this_dict.items())

nama_train_data = switch_dict_key_values(train_data.class_indices)
print(nama_train_data)
# Out:
# {0: 'B', 1: 'D', 2: 'G', 3: 'H', 4: 'H1', 5: 'K', 6: 'L', 7: 'M', 8: 'N', 9: 'P', 10: 'Q', 11: 'R', 12: 'S', 13: 'S1', 14: 'S2', 15: 'T', 16: 'T1', 17: 'W', 18: 'Y', 19: 'Z', 20: 'koma', 21: 'petik'}

# %% [markdown]
# Sekarang terlihat bahwa `0` merepresentasikan `X` dan `1` merepresentasikan `X` dst.
#
# Untuk test pertama kita, mari kita coba `X` terlebih dahulu.

# %%
from keras.preprocessing import image
import numpy as np

img = image.load_img(TesB, target_size = (size_, size_))
img = image.img_to_array(img)
img = np.expand_dims(img, axis = 0)

hasil = model.predict_classes(img)
print("File gambar [", "B", "] diprediksi sebagai", hasil, "alias terbaca sebagai :: ", nama_train_data[hasil[0]], ".")
# Out:
# File gambar [ B ] diprediksi sebagai [0] alias terbaca sebagai ::  B .
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %% [markdown]
# Untuk test kedua kita, mari kita coba `s` sebagai file testing.

# %%
img = image.load_img(TesD, target_size = (size_, size_))
img = image.img_to_array(img)
img = np.expand_dims(img, axis = 0)

hasil = model.predict_classes(img)
print("File gambar [", "D", "] diprediksi sebagai", hasil, "alias terbaca sebagai :: ", nama_train_data[hasil[0]], ".")
# Out:
# File gambar [ D ] diprediksi sebagai [1] alias terbaca sebagai ::  D .
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
img = image.load_img(TesG, target_size = (size_, size_))
img = image.img_to_array(img)
img = np.expand_dims(img, axis = 0)

hasil = model.predict_classes(img)
print("File gambar [", "G", "] diprediksi sebagai", hasil, "alias terbaca sebagai :: ", nama_train_data[hasil[0]], ".")
# Out:
# File gambar [ G ] diprediksi sebagai [2] alias terbaca sebagai ::  G .
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
lol = glob.glob("dataset_pho/test/B/*.jpg")

total = 0
for haha in lol:
  img = image.load_img(haha, target_size = (16, 16))
  img = image.img_to_array(img)
  img = np.expand_dims(img, axis = 0)

  hasil = model.predict_classes(img)
  #print("File gambar [s] diprediksi sebagai", hasil, "alias terbaca sebagai :: ", nama_train_data[hasil[0][0]], ".")
  total += (0 == hasil[0])*1
print(total/len(lol))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 1.0

# %%
lol = glob.glob("dataset_pho/test/D/*.jpg")

total = 0
for haha in lol:
  img = image.load_img(haha, target_size = (16, 16))
  img = image.img_to_array(img)
  img = np.expand_dims(img, axis = 0)

  hasil = model.predict_classes(img)
  #print("File gambar [s] diprediksi sebagai", hasil, "alias terbaca sebagai :: ", nama_train_data[hasil[0][0]], ".")
  total += (1 == hasil[0])*1
print(total/len(lol))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 1.0
